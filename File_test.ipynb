# %%
# %%writefile test_1.txt
# This is first line.
# This is second line.
# Out:
# Writing test_1.txt

# %%
obj1 = open('test_1.txt')    #  deault read mode.
obj1.read()
for line in open('test_1.txt'):
  print(line)
# Out:
# This is first line.
#
# This is second line.

# %%
obj1.seek(0)
obj1.readlines()
# Out:
# ['This is first line.\n', 'This is second line.\n']

# %%
type(obj1.readlines())
# Out:
# list

# %%
obj1 = open('test_1.txt', mode = 'w+')
obj1.write('This is new file.')
obj1.seek(0)
print(obj1.read())
obj1.close()
# Out:
# This is new file.

# %%
from io import StringIO

s = 'This is string.'
obj1 = StringIO(s)
print(type(obj1))
obj1.read()
# Out:
# <class '_io.StringIO'>
# 'This is string.'

# %%
obj1.write("This is second line in object.")  # append line each time.
obj1.seek(0)
obj1.read()
# Out:
# 'This is string.This is second line in object.This is second line in object.'
